# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Anil\Projects\CricketScorePredictor-master\data\ipl.csv')

# %% [markdown]
# # Reading file in Pandas

# %%
df.read_csv("file_path")
df.read_xlsx("file_path")
df.read_sql_query("query",con)
df.read_json("file_path")

postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
.format(username=POSTGRES_USERNAME,
password=POSTGRES_PASSWORD,
ipaddress=POSTGRES_ADDRESS,
port=POSTGRES_PORT,
dbname=POSTGRES_DBNAME))
# Create the connection
cnx = create_engine(postgres_str)

df = pd.read_sql_query(‘’’SELECT * FROM my_view’’’, con=cnx))

# %%
print("Anil")
# Out:
# Anil

# %%
a = "Anil"

# %%
age = 26

# %%
print(a)
# Out:
# Anil

# %%
place = "Mumbai"

# %% [markdown]
# # Random print functions

# %%
print("The name of the employee is {} and his age is {} and his place of residence is {}".format(a,age,place))
# Out:
# The name of the employee is Anil and his age is 26 and his place of residence is Mumbai

# %%
print(f"The name of the employee is {a} and his age is {age} and his place of residence is {place}")
# Out:
# The name of the employee is Anil and his age is 26 and his place of residence is Mumbai

# %%
df
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %% [markdown]
# # Create a Dataframe using Dictionary

# %%
df_temp = pd.DataFrame(
{
    "Name" : ['Anil','Vivek','shubham','Sumeet'],
    "Age" : [20,21,22,23],
    "Gender" : ["M","M","M","M"]    
}
)

# %%
df_temp
# Out:
#       Name  Age Gender
# 0     Anil   20      M
# 1    Vivek   21      M
# 2  shubham   22      M
# 3   Sumeet   23      M

# %%
dir(df_temp)
# Out:
# ['Age',
#  'Gender',
#  'Name',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
df.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
df.tail()
# Out:
#        mid        date                                      venue  \
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#              bat_team               bowl_team     batsman        bowler  runs  \
# 76009  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   121
# 76010  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   127
# 76011  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   128
# 76012  Mumbai Indians  Rising Pune Supergiant  MG Johnson  DT Christian   129
# 76013  Mumbai Indians  Rising Pune Supergiant   KH Pandya  DT Christian   129
#
#        wickets  overs  runs_last_5  wickets_last_5  striker  non-striker  \
# ...

# %%
df.shape
# Out:
# (76014, 15)

# %%
df2 = df[1000:1200]

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
a = df2['mid']

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# 1000     9
# 1001     9
# 1002     9
# 1003     9
# 1004     9
#         ..
# 1195    10
# 1196    10
# 1197    10
# 1198    10
# 1199    10
# Name: mid, Length: 200, dtype: int64

# %%
b = df2[['mid']]

# %%
b
# Out:
#       mid
# 1000    9
# 1001    9
# 1002    9
# 1003    9
# 1004    9
# ...   ...
# 1195   10
# 1196   10
# 1197   10
# 1198   10
# 1199   10
#
# [200 rows x 1 columns]

# %%
df.shape
# Out:
# (76014, 15)

# %%
df.columns
# Out:
# Index(['mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman', 'bowler',
#        'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5', 'striker',
#        'non-striker', 'total'],
#       dtype='object')

# %%
df['mid'] #This is a series

# %%
df.mid

# %%
df[['mid','venue','bat_team']]
# Out:
#        mid                                      venue               bat_team
# 0        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 1        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 2        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 3        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# 4        1                      M Chinnaswamy Stadium  Kolkata Knight Riders
# ...    ...                                        ...                    ...
# 76009  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76010  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76011  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76012  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
# 76013  617  Rajiv Gandhi International Stadium, Uppal         Mumbai Indians
#
# [76014 rows x 3 columns]

# %%
df.mid
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#         ...
# 76009    617
# 76010    617
# 76011    617
# 76012    617
# 76013    617
# Name: mid, Length: 76014, dtype: int64

# %%
df
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
df['total'].describe()
# Out:
# count    76014.000000
# mean       160.901452
# std         29.246231
# min         67.000000
# 25%        142.000000
# 50%        162.000000
# 75%        181.000000
# max        263.000000
# Name: total, dtype: float64

# %%
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
df[df.total == df.total.max()]
# Out:
#        mid        date                  venue                     bat_team  \
# 42229  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42230  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42231  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42232  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42233  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...    ...         ...                    ...                          ...
# 42352  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42353  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42354  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42355  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 42356  343  2013-04-23  M Chinnaswamy Stadium  Royal Challengers Bangalore
#
# ...

# %%
df_temp
# Out:
# 263

# %%
df.total == df.total.min()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 76009    False
# 76010    False
# 76011    False
# 76012    False
# 76013    False
# Name: total, Length: 76014, dtype: bool

# %%
df[df.total = df.total.min()]
# Out:
#   File "C:\Users\AN2025~1\AppData\Local\Temp/ipykernel_6256/2384861536.py", line 1
#     df[df.total = df.total.min()]
#                 ^
# SyntaxError: invalid syntax

# %%
df['city'][df.temp = 67]

# %%
df['venue'][2000:2300]
# Out:
# 2000          Feroz Shah Kotla
# 2001          Feroz Shah Kotla
# 2002          Feroz Shah Kotla
# 2003          Feroz Shah Kotla
# 2004          Feroz Shah Kotla
#                  ...
# 2295    Sawai Mansingh Stadium
# 2296    Sawai Mansingh Stadium
# 2297    Sawai Mansingh Stadium
# 2298    Sawai Mansingh Stadium
# 2299    Sawai Mansingh Stadium
# Name: venue, Length: 300, dtype: object

# %%
1   Anil 100
2   Anil 100 
3   Anil 200
4   a     ff
5    b   jir
6    c    ror 
7    d   jfuj
8    e   kfi
9   f   ifr
10  g   rir

# %%
df2 = df[['mid','date','bat_team']]

# %%
df2.to_csv(r'C:\Anil\Projects\DS Training\temp.csv')

# %%
df2
# Out:
#        mid        date               bat_team
# 0        1  2008-04-18  Kolkata Knight Riders
# 1        1  2008-04-18  Kolkata Knight Riders
# 2        1  2008-04-18  Kolkata Knight Riders
# 3        1  2008-04-18  Kolkata Knight Riders
# 4        1  2008-04-18  Kolkata Knight Riders
# ...    ...         ...                    ...
# 76009  617  2017-05-21         Mumbai Indians
# 76010  617  2017-05-21         Mumbai Indians
# 76011  617  2017-05-21         Mumbai Indians
# 76012  617  2017-05-21         Mumbai Indians
# 76013  617  2017-05-21         Mumbai Indians
#
# [76014 rows x 3 columns]

# %%
#group by

# %%
df.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# ...

# %%
df2 = df.groupby('venue')

# %%
df2

# %%
for i,j in df2:
    print(i)
    print(j)
    df2.get_group(i)

# %%
df2.get_group('Dr DY Patil Sports Academy')
# Out:
#        mid        date                       venue        bat_team  \
# 1482    13  2008-04-27  Dr DY Patil Sports Academy  Mumbai Indians
# 1483    13  2008-04-27  Dr DY Patil Sports Academy  Mumbai Indians
# 1484    13  2008-04-27  Dr DY Patil Sports Academy  Mumbai Indians
# 1485    13  2008-04-27  Dr DY Patil Sports Academy  Mumbai Indians
# 1486    13  2008-04-27  Dr DY Patil Sports Academy  Mumbai Indians
# ...    ...         ...                         ...             ...
# 28563  231  2011-05-19  Dr DY Patil Sports Academy   Pune Warriors
# 28564  231  2011-05-19  Dr DY Patil Sports Academy   Pune Warriors
# 28565  231  2011-05-19  Dr DY Patil Sports Academy   Pune Warriors
# 28566  231  2011-05-19  Dr DY Patil Sports Academy   Pune Warriors
# 28567  231  2011-05-19  Dr DY Patil Sports Academy   Pune Warriors
#
#                    bowl_team        batsman    bowler  runs  wickets  overs  \
# 1482         Deccan Chargers       L Ronchi  RP Singh     0        0    0.1
# ...

# %%
df_yuvraj = df[df.batsman == 'Yuvraj Singh'].reset_index()

# %%
df_yuvraj
# Out:
#      index  mid        date                   venue             bat_team  \
# 0      657    6  2008-04-21  Sawai Mansingh Stadium      Kings XI Punjab
# 1      658    6  2008-04-21  Sawai Mansingh Stadium      Kings XI Punjab
# 2      659    6  2008-04-21  Sawai Mansingh Stadium      Kings XI Punjab
# 3      660    6  2008-04-21  Sawai Mansingh Stadium      Kings XI Punjab
# 4      663    6  2008-04-21  Sawai Mansingh Stadium      Kings XI Punjab
# ..     ...  ...         ...                     ...                  ...
# 975  73681  598  2017-05-02        Feroz Shah Kotla  Sunrisers Hyderabad
# 976  73682  598  2017-05-02        Feroz Shah Kotla  Sunrisers Hyderabad
# 977  73683  598  2017-05-02        Feroz Shah Kotla  Sunrisers Hyderabad
# 978  73685  598  2017-05-02        Feroz Shah Kotla  Sunrisers Hyderabad
# 979  73686  598  2017-05-02        Feroz Shah Kotla  Sunrisers Hyderabad
#
#             bowl_team       batsman      bowler  runs  wickets  overs  \
# ...

# %%
df_yuvraj.columns
# Out:
# Index(['index', 'mid', 'date', 'venue', 'bat_team', 'bowl_team', 'batsman',
#        'bowler', 'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5',
#        'striker', 'non-striker', 'total'],
#       dtype='object')

# %%
df_yuvraj.shape
# Out:
# (980, 16)

# %%
df['batsman'].unique()
# Out:
# array(['SC Ganguly', 'BB McCullum', 'RT Ponting', 'DJ Hussey',
#        'Mohammad Hafeez', 'PA Patel', 'ML Hayden', 'MEK Hussey',
#        'MS Dhoni', 'SK Raina', 'JDP Oram', 'S Badrinath', 'T Kohli',
#        'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja',
#        'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'L Ronchi',
#        'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah',
#        'AM Nayar', 'SM Pollock', 'Harbhajan Singh', 'AC Gilchrist',
#        'Y Venugopal Rao', 'VVS Laxman', 'A Symonds', 'RG Sharma',
#        'SB Styris', 'AS Yadav', 'SB Bangar', 'WPUJC Vaas', 'RP Singh',
#        'K Goel', 'JR Hopes', 'KC Sangakkara', 'DPMD Jayawardene',
#        'Yuvraj Singh', 'IK Pathan', 'S Sohal', 'B Lee', 'PP Chawla',
#        'WA Mota', 'Shahid Afridi', 'RR Sarwan', 'S Sreesanth',
#        'VRV Singh', 'S Chanderpaul', 'R Dravid', 'LRPL Taylor',
#        'JH Kallis', 'V Kohli', 'MV Boucher', 'P Kumar', 'SB Joshi',
# ...

# %%
df_ganguly = df[df['batsman'] == "SC Ganguly"]

# %%
df_yuv_gan = pd.concat([df_yuvraj,df_ganguly],axis=0)

# %%
df_yuv_gan.to_csv("C:\Anil\Projects\DS Training\player.csv")

# %%
df_yuv_gan
# Out:
#        index  mid        date                       venue         bat_team  \
# 0      657.0    6  2008-04-21      Sawai Mansingh Stadium  Kings XI Punjab
# 1      658.0    6  2008-04-21      Sawai Mansingh Stadium  Kings XI Punjab
# 2      659.0    6  2008-04-21      Sawai Mansingh Stadium  Kings XI Punjab
# 3      660.0    6  2008-04-21      Sawai Mansingh Stadium  Kings XI Punjab
# 4      663.0    6  2008-04-21      Sawai Mansingh Stadium  Kings XI Punjab
# ...      ...  ...         ...                         ...              ...
# 35709    NaN  290  2012-05-08  Subrata Roy Sahara Stadium    Pune Warriors
# 35711    NaN  290  2012-05-08  Subrata Roy Sahara Stadium    Pune Warriors
# 35713    NaN  290  2012-05-08  Subrata Roy Sahara Stadium    Pune Warriors
# 35714    NaN  290  2012-05-08  Subrata Roy Sahara Stadium    Pune Warriors
# 35716    NaN  290  2012-05-08  Subrata Roy Sahara Stadium    Pune Warriors
#
# ...

# %% [raw]
# df_yuv_gan

# %%
df = pd.DataFrame([10,20,30],index=[3,1,2])

# %%
df
# Out:
#     0
# 3  10
# 1  20
# 2  30

# %%
df.loc[3]   #this works on index
# Out:
# 0    10
# Name: 3, dtype: int64

# %%
df.iloc[3]   #This works on row Number
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\AN2025~1\AppData\Local\Temp/ipykernel_6256/17153105.py in <module>
# ----> 1 df.iloc[3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
#List Assignment
#https://www.codesdope.com/practice/python-make-a-list/
